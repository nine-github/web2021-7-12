# %%
from wordcloud import WordCloud
import numpy as np
import jieba
from snownlp import SnowNLP
import pandas as pd
from PIL import Image
import os
import jieba.analyse as ana
import nltk

# %%
path="音乐区弹幕"
filenames=os.listdir(path)
result="音乐区弹幕.txt"
f= open(result, 'w+', encoding="utf-8")

# %%
for filename in filenames:
    filepath = path + '/'
    filepath = filepath + filename
    for line in open(filepath, encoding="utf-8"):
        f.writelines(line)
        f.write('\n')
f.close()

# %%
file=open(result,"r",encoding='utf-8')
text=file.read()
text=" ".join(jieba.lcut(text))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\DELL\AppData\Local\Temp\jieba.cache
# Loading model cost 0.807 seconds.
# Prefix dict has been built successfully.

# %%
fdist=nltk.FreqDist(text)
fdist.most_common(500)
# Out:
# [(' ', 89705),
#  ('\n', 22650),
#  ('○', 4651),
#  ('♡', 2670),
#  ('哈', 2484),
#  ('！', 2338),
#  ('了', 2091),
#  ('啊', 2059),
#  ('的', 1674),
#  ('好', 1596),
#  ('我', 1507),
#  ('"', 1465),
#  ('，', 1166),
#  (',', 1153),
#  ('生', 1090),
#  ('轩', 1088),
#  ('◎', 1082),
#  ('一', 1034),
#  ('快', 992),
#  ('☆', 991),
#  ('乐', 984),
#  ('日', 979),
#  ('k', 955),
#  ('这', 888),
#  ('是', 886),
#  ('0', 849),
#  ('不', 819),
#  ('你', 789),
#  ('△', 774),
#  ('▼', 772),
#  ('宋', 707),
#  ('亚', 701),
#  ('1', 646),
#  ('s', 630),
#  ('？', 609),
#  ('3', 545),
#  ('来', 541),
#  ('h', 523),
#  ('天', 511),
#  ('听', 502),
#  ('2', 497),
#  ('y', 481),
#  ('太', 475),
#  ('爱', 468),
#  ('有', 413),
#  ('个', 395),
#  ('5', 390),
#  ('依', 385),
#  ('4', 369),
#  ('9', 357),
#  ('.', 349),
#  ('谢', 342),
#  ('真', 340),
#  ('小', 337),
#  ('绝', 332),
#  ('人', 325),
#  ('分', 324),
#  ('可', 310),
#  ('就', 307),
#  ('歌', 300),
#  ('老', 291),
#  ('a', 290),
#  ('呜', 286),
#  ('唱', 285),
#  ('。', 281),
#  ('耶', 278),
#  ('么', 276),
#  ('“', 276),
#  ('”', 275),
#  ('d', 274),
#  ('在', 271),
#  ('音', 257),
#  ('能', 256),
#  ('到', 249),
#  ('钟', 243),
#  ('看', 237),
#  ('✧', 236),
#  ('都', 231),
#  ('要', 228),
#  ('i', 228),
#  ('还', 227),
#  ('意', 227),
#  ('样', 221),
#  ('6', 220),
#  ('啦', 218),
#  ('想', 217),
#  ('也', 217),
#  ('起', 207),
#  ('热', 207),
#  ('感', 204),
#  ('为', 204),
#  ('o', 202),
#  ('愿', 200),
#  ('像', 197),
#  ('n', 194),
#  ('时', 192),
#  ('e', 183),
#  ('没', 182),
#  ('婆', 182),
#  ('文', 180),
#  ('去', 179),
#  ('L', 179),
#  ('儿', 178),
#  ('美', 177),
#  ('*', 176),
#  ('们', 170),
#  ('心', 168),
#  ('吧', 167),
#  ('前', 165),
#  ('高', 164),
#  ('吗', 163),
#  ('那', 163),
#  ('喜', 162),
#  ('无', 160),
#  ('♢', 160),
#  ('大', 159),
#  ('欢', 156),
#  ('得', 155),
#  ('会', 154),
#  ('帅', 154),
#  ('宝', 153),
#  ('再', 152),
#  ('上', 152),
#  ('下', 151),
#  ('姐', 151),
#  ('过', 151),
#  ('m', 151),
#  ('哥', 151),
#  ('声', 149),
#  ('着', 149),
#  ('-', 149),
#  ('很', 147),
#  ('w', 146),
#  ('子', 145),
#  ('中', 144),
#  ('以', 143),
#  ('!', 140),
#  ('棒', 139),
#  ('觉', 139),
#  ('乎', 138),
#  ('神', 137),
#  ('贝', 136),
#  ('开', 134),
#  ('别', 131),
#  ('~', 130),
#  ('7', 130),
#  ('说', 129),
#  ('里', 127),
#  ('哭', 125),
#  ('8', 124),
#  ('～', 123),
#  ('点', 122),
#  ('u', 121),
#  ('什', 121),
#  ('给', 119),
#  ('林', 119),
#  ('最', 118),
#  ('出', 118),
#  ('世', 118),
#  ('S', 116),
#  ('吃', 114),
#  ('年', 114),
#  ('长', 112),
#  ('多', 111),
#  ('H', 111),
#  ('次', 110),
#  ('呀', 110),
#  ('对', 109),
#  ('自', 109),
#  ('词', 109),
#  ('实', 109),
#  ('永', 107),
#  ('直', 106),
#  ('远', 105),
#  ('主', 105),
#  ('模', 105),
#  ('首', 102),
#  ('◯', 102),
#  ('笑', 101),
#  ('全', 100),
#  ('后', 99),
#  ('牛', 99),
#  ('遍', 98),
#  ('经', 98),
#  ('头', 98),
#  ('三', 97),
#  ('见', 96),
#  ('あ', 96),
#  ('现', 95),
#  ('字', 94),
#  ('r', 94),
#  ('囍', 94),
#  ('只', 93),
#  ('知', 93),
#  ('嘉', 91),
#  ('手', 91),
#  ('因', 91),
#  ('卧', 91),
#  ('槽', 91),
#  ('泪', 90),
#  ('道', 90),
#  ('…', 89),
#  ('死', 89),
#  (']', 88),
#  ('他', 87),
#  ('界', 86),
#  ('把', 86),
#  ('家', 85),
#  ('幕', 84),
#  ('情', 84),
#  ('和', 83),
#  ('陈', 83),
#  ('之', 81),
#  ('国', 80),
#  ('场', 79),
#  ('百', 79),
#  ('方', 79),
#  ('眼', 78),
#  ('曲', 77),
#  ('[', 76),
#  ('回', 74),
#  ('打', 74),
#  ('原', 74),
#  ('面', 73),
#  ('风', 73),
#  ('十', 73),
#  ('定', 71),
#  ('女', 71),
#  ('怕', 70),
#  ('Y', 69),
#  ('p', 69),
#  ('明', 68),
#  ('第', 68),
#  ('怎', 68),
#  ('己', 67),
#  ('被', 67),
#  ('皮', 66),
#  ('连', 66),
#  ('发', 65),
#  ('所', 64),
#  ('命', 64),
#  ('恋', 64),
#  ('调', 64),
#  ('杰', 64),
#  ('本', 63),
#  ('舞', 63),
#  ('t', 63),
#  ('偷', 63),
#  ('公', 62),
#  ('初', 62),
#  ('g', 62),
#  ('破', 62),
#  ('洛', 62),
#  ('哇', 61),
#  ('如', 61),
#  ('电', 61),
#  ('于', 61),
#  ('活', 60),
#  ('救', 60),
#  ('然', 60),
#  ('j', 60),
#  ('俊', 60),
#  ('入', 59),
#  ('迅', 59),
#  ('目', 58),
#  ('已', 58),
#  ('万', 58),
#  ('力', 57),
#  ('曾', 57),
#  ('走', 57),
#  ('猫', 57),
#  ('抄', 57),
#  ('版', 56),
#  ('岛', 56),
#  ('台', 56),
#  ('郭', 56),
#  ('动', 55),
#  ('少', 55),
#  ('害', 54),
#  ('名', 54),
#  ('身', 54),
#  ('耳', 54),
#  ('注', 54),
#  ('耀', 54),
#  ('临', 54),
#  ('完', 53),
#  ('口', 53),
#  ('重', 53),
#  ('奕', 53),
#  ('魂', 52),
#  ('接', 52),
#  ('影', 52),
#  ('越', 52),
#  ('f', 52),
#  ('c', 51),
#  ('防', 51),
#  ('婚', 51),
#  ('冬', 51),
#  ('用', 50),
#  ('西', 50),
#  ('跳', 50),
#  ('更', 49),
#  ('又', 49),
#  ('加', 49),
#  ('话', 49),
#  ('色', 49),
#  ('亲', 49),
#  ('J', 49),
#  ('光', 48),
#  ('蓝', 48),
#  ('投', 47),
#  ('做', 47),
#  ('每', 47),
#  ('两', 47),
#  ('草', 47),
#  ('币', 46),
#  ('将', 46),
#  ('D', 46),
#  ('住', 46),
#  ('放', 46),
#  ('♪', 46),
#  ('刘', 46),
#  ('吓', 46),
#  ('但', 45),
#  ('气', 45),
#  ('の', 45),
#  ('行', 45),
#  ('而', 44),
#  ('强', 44),
#  ('门', 44),
#  ('呢', 44),
#  ('冲', 44),
#  ('合', 44),
#  ('难', 43),
#  ('海', 42),
#  ('幸', 42),
#  ('鸡', 42),
#  ('望', 42),
#  ('语', 42),
#  ('哦', 42),
#  ('受', 42),
#  ('白', 42),
#  ('叫', 42),
#  ('、', 42),
#  ('菜', 42),
#  ('l', 41),
#  ('她', 41),
#  ('事', 41),
#  ('写', 41),
#  ('相', 41),
#  ('丝', 41),
#  ('错', 41),
#  ('八', 41),
#  ('间', 40),
#  ('学', 40),
#  ('体', 40),
#  ('法', 40),
#  ('b', 40),
#  ('果', 40),
#  ('卡', 40),
#  ('信', 40),
#  ('礼', 40),
#  ('馆', 40),
#  ('疙', 39),
#  ('瘩', 39),
#  ('正', 39),
#  ('刚', 39),
#  ('?', 39),
#  ('许', 39),
#  ('怪', 39),
#  ('骂', 39),
#  ('味', 39),
#  ('福', 38),
#  ('让', 38),
#  ('当', 38),
#  ('（', 38),
#  ('超', 38),
#  ('哪', 38),
#  ('与', 38),
#  ('震', 38),
#  ('带', 37),
#  ('候', 36),
#  ('成', 36),
#  ('稳', 36),
#  ('男', 36),
#  ('《', 36),
#  ('》', 36),
#  ('阿', 36),
#  ('王', 36),
#  ('弹', 36),
#  ('填', 36),
#  ('星', 35),
#  ('比', 35),
#  ('新', 35),
#  ('温', 35),
#  ('立', 35),
#  ('转', 35),
#  ('够', 35),
#  ('机', 35),
#  ('亿', 35),
#  ('装', 35),
#  ('地', 34),
#  ('段', 34),
#  ('夏', 34),
#  ('火', 34),
#  ('系', 34),
#  ('友', 34),
#  ('水', 34),
#  ('哟', 34),
#  ('苦', 33),
#  ('厉', 33),
#  ('者', 33),
#  ('T', 33),
#  ('抱', 33),
#  ('种', 33),
#  ('粉', 33),
#  ('饿', 33),
#  ('韩', 33),
#  ('二', 32),
#  ('空', 32),
#  ('亮', 32),
#  ('O', 32),
#  ('^', 32),
#  ('华', 32),
#  ('逼', 32),
#  ('似', 32),
#  ('袭', 32),
#  ('M', 31),
#  ('晚', 31),
#  ('）', 31),
#  ('等', 31),
#  ('同', 31),
#  ('进', 31),
#  ('谁', 31),
#  ('飞', 31),
#  ('此', 31),
#  ('车', 31),
#  ('结', 31),
#  ('滴', 30),
#  ('满', 30),
#  ('才', 30),
#  ('量', 30),
#  ('表', 30),
#  ('妈', 30),
#  ('几', 30),
#  ('或', 30),
#  ('跪', 30),
#  ('干', 30),
#  ('嘛', 29),
#  ('切', 29),
#  ('离', 29),
#  ('作', 29),
#  ('变', 29),
#  ('该', 29),
#  ('花', 29),
#  ('拿', 29),
#  ('余', 29),
#  ('任', 29),
#  ('：', 29),
#  ('憨', 29),
#  ('些', 28),
#  ('青', 28),
#  ('N', 28),
#  ('请', 28),
#  ('深', 28),
#  ('理', 28),
#  ('句', 28),
#  ('\\', 28),
#  ('韵', 28),
#  ('伤', 27),
#  ('今', 27),
#  ('·', 27),
#  ('鱼', 27),
#  ('木', 27),
#  ('黑', 27),
#  ('服', 27),
#  ('钱', 27),
#  ('伙', 27),
#  ('A', 26),
#  ('站', 26),
#  ('竟', 26),
#  ('终', 26),
#  ('い', 26),
#  ('熟', 26),
#  ('必', 26),
#  ('算', 26),
#  ('爷', 25),
#  ('级', 25),
#  ('沉', 25),
#  ('何', 25),
#  ('祝', 25),
#  ('缘', 25),
#  ('早', 25),
#  ('常', 25),
#  ('(', 25),
#  ('应', 25),
#  ('敌', 25),
#  ('绒', 25),
#  ('杀', 25),
#  ('游', 25)]

# %%
ana.set_stop_words("停用词.txt")
text1=ana.extract_tags(text,topK=1000)
text1=" ".join(text1)
text1
# Out:
# '生日快乐 宋亚轩 啊啊啊 哈哈哈 天依 kksk yyds 哈哈哈哈 好听 轩轩 分钟 热乎 卧槽 老婆 愿意 谢谢 呜呜 宝贝儿 可爱 真的 文轩 一模一样 好帅 轩哥 喜欢 美嘉 SimHei 林俊杰 这个 4399 主唱 好好 哈哈 首歌 泪目 高能 永远 太绝 500 陈奕迅 小时 破防 初恋 字幕 郭冬临 高音 太棒了 感觉 救命 刘耀文 林魂 姐姐 太帅 打卡 前方 老公 一了百了 亿遍 声音 鸡皮疙瘩 真实 歌词 馆长 不是 舞台 我们 世界 感谢 抄袭 三连 好看 YYDS 亲爱 就是 好绝 偷国 什么 唱歌 现场 因为 别怕 弹幕 可以 5.3 知道 注入 绝绝子 依洛天 开口 西装 曾经 怎么 所长 这么 一样 好美 好像 开头 ... 亚轩 80 蓝丝绒 这里 觉得 自己 还是 门把手 宝贝 余震 一起 厉害 我要 300w JJ 电影 好家伙 一直 一个 滴神 我来 太强 好棒 起立 少年 音量 投币 10 ka 300 别骂 重投 离谱 无敌 再见 原版 原唱 前任 婚礼 咬字 这样 22 华风夏韵 洛水 热热 之神 加油 一定 na 15 太像 调小 吃瓜 一遍 幸福 爷青回 19 700 450 1000 陈粒 不要 填词 辛苦 第一 这歌 有点 三百万 为什么 ta no 4400 狼鱼 纯爱 女主 Eason 还给 别搞 好好看 一次 这首 老林 一生 没有 小宝贝 翻唱 直接 遗憾 up FangSong 5.2 4399439943994399 362 237 这世 预警 全体 起飞