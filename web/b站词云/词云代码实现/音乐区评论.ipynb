# %%
from wordcloud import WordCloud
import numpy as np
import jieba
from snownlp import SnowNLP
import pandas as pd
from PIL import Image
import os
import jieba.analyse as ana
import nltk

# %%
data=pd.read_excel('评论区/音乐区用户信息.xlsx',header=None,usecols = [6],squeeze  = False)
data
# Out:
#                                                       6
# 0                                               comment
# 1     3号父亲出车祸，伤的很重，到现在还躺在重症，到现在也没恢复意识，10号早晨奶奶走了。活了二十...
# 2     今天我生日，一个一起玩原神的朋友看见我游戏内的生日设置，给我说了一声生日快乐，破防了，快五年...
# 3     停一下，朋友，停一下。先不要往下翻，请听我说：\n    你真的很棒，一路走来，你的勇气和真...
# 4     “中岛美嘉10年患病接近失声 停止一切演唱活动  并发症导致耳疾 听力下降  期间冷嘲热讽说...
# ...                                                 ...
# 4890                                                 第一
# 4891                                                 来了
# 4892  好兄弟们，我明天出院了！今天就来这首歌了，这是缘分吗？\n极重度焦虑和重度抑郁的奔二患者\n...
# 4893                                               [滑稽]
# 4894                                               来了来了
#
# [4895 rows x 1 columns]

# %%
data= data.apply(lambda x: str(x))

# %%
text=data.values.tolist()
text=" ".join(text)
text=jieba.lcut(text)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\DELL\AppData\Local\Temp\jieba.cache
# Loading model cost 0.598 seconds.
# Prefix dict has been built successfully.

# %%
fdist=nltk.FreqDist(text)
fdist.most_common(500)
# Out:
# [(' ', 350),
#  ('，', 15),
#  ('\n', 11),
#  ('了', 9),
#  ('...', 6),
#  ('的', 5),
#  ('我', 5),
#  ('来', 4),
#  ('说', 3),
#  ('\\', 3),
#  ('n', 3),
#  (':', 3),
#  ('3', 2),
#  ('号', 2),
#  ('到', 2),
#  ('现在', 2),
#  ('10', 2),
#  ('。', 2),
#  ('今天', 2),
#  ('生日', 2),
#  ('朋友', 2),
#  ('停', 2),
#  ('一下', 2),
#  ('你', 2),
#  ('和', 2),
#  ('重度', 2),
#  (',', 2),
#  ('0', 1),
#  ('comment', 1),
#  ('1', 1),
#  ('父亲', 1),
#  ('出车祸', 1),
#  ('伤', 1),
#  ('很重', 1),
#  ('还', 1),
#  ('躺', 1),
#  ('在', 1),
#  ('重症', 1),
#  ('也', 1),
#  ('没', 1),
#  ('恢复', 1),
#  ('意识', 1),
#  ('早晨', 1),
#  ('奶奶', 1),
#  ('走', 1),
#  ('活', 1),
#  ('二十', 1),
#  ('2', 1),
#  ('一个', 1),
#  ('一起', 1),
#  ('玩', 1),
#  ('原神', 1),
#  ('看见', 1),
#  ('游戏', 1),
#  ('内', 1),
#  ('设置', 1),
#  ('给', 1),
#  ('一声', 1),
#  ('生日快乐', 1),
#  ('破防', 1),
#  ('快', 1),
#  ('五年', 1),
#  ('先', 1),
#  ('不要', 1),
#  ('往下', 1),
#  ('翻', 1),
#  ('请', 1),
#  ('听', 1),
#  ('：', 1),
#  ('真的', 1),
#  ('很棒', 1),
#  ('一路', 1),
#  ('走来', 1),
# ...

# %%
ana.set_stop_words("停用词.txt")
text=" ".join(text)
text1=ana.extract_tags(text,topK=500)
text1=" ".join(text1)
text1
# Out:
# '10 重度 生日 耳疾 生日快乐 出车祸 原神 破防 美嘉 Name Length 朋友 很棒 冷嘲热讽 首歌 今天 一下 缘分 失声 听力 抑郁 滑稽 出院 并发症 患病 重症 演唱 焦虑 现在 二十 勇气 走来 游戏 早晨 奶奶 五年 明天 一路 意识 设置 患者 停止 兄弟 接近 真的 父亲 恢复 第一 一声 期间 导致 看见 下降 一切 不要 一起 活动 这是 一个'

# %%
mask=np.array(Image.open("电1.jpg"))
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
yy=WordCloud(background_color="white",font_path="Font/msyh.ttc",max_words=500,width=250,height=250,repeat=False,max_font_size=70,min_font_size=10,mask=mask,colormap="RdPu")

# %%
yy.generate(text1)

# %%
yy.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1028x998 at 0x156C22B9BE0>

# %%
yy.to_file("音乐区评论.png")
