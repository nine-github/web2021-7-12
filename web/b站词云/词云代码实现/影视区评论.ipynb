# %%
from wordcloud import WordCloud
import numpy as np
import jieba
from snownlp import SnowNLP
import pandas as pd
from PIL import Image
import os
import jieba.analyse as ana
import nltk

# %%
data=pd.read_excel('评论区/影视区用户信息.xlsx',header=None,usecols = [6],squeeze  = False)
data
# Out:
#                                                       6
# 0                                               comment
# 1     说真的，我就是因为这剧和女友分手。前女友居然和我说让我多学学这剧里的男主。。。说白了就是她要...
# 2     粉丝的下一句话：鹿人恰烂钱，收了鹿晗的钱，他俩都姓鹿。哈哈哈，真有这么说的话鹿人把他挂出来，...
# 3                                   演员可以凭剧获奖，为什么不能凭剧挨骂？
# 4                                       我的评价是：加大力度[给心心]
# ...                                                 ...
# 8627                                              这就是资本
# 8628  国内徒有虚名的厨师出了新菜品，这次的菜品叫做《你微笑时很美》。菜肴盖着的时候已是臭气熏天，众...
# 8629                                             粉丝是真脑瘫
# 8630                             丢脸.....（指你微笑时挺sb[辣眼睛]）
# 8631                                  尼玛这还投资两亿 都花钱请演员了吗
#
# [8632 rows x 1 columns]

# %%
data= data.apply(lambda x: str(x))

# %%
text=data.values.tolist()
text=" ".join(text)
text=jieba.lcut(text)

# %%
fdist=nltk.FreqDist(text)
fdist.most_common(500)
# Out:
# [(' ', 367),
#  ('\n', 11),
#  ('，', 8),
#  ('的', 7),
#  ('。', 6),
#  ('我', 4),
#  ('...', 4),
#  ('就是', 3),
#  ('这', 3),
#  ('了', 3),
#  ('是', 3),
#  (':', 3),
#  ('和', 2),
#  ('说', 2),
#  ('粉丝', 2),
#  ('：', 2),
#  ('鹿人', 2),
#  ('钱', 2),
#  ('都', 2),
#  ('演员', 2),
#  ('凭剧', 2),
#  ('[', 2),
#  (']', 2),
#  ('菜品', 2),
#  ('你', 2),
#  ('微笑', 2),
#  ('时', 2),
#  (',', 2),
#  ('0', 1),
#  ('comment', 1),
#  ('1', 1),
#  ('说真的', 1),
#  ('因为', 1),
#  ('这剧', 1),
#  ('女友', 1),
#  ('分手', 1),
#  ('前女友', 1),
#  ('居然', 1),
#  ('让', 1),
#  ('多', 1),
#  ('学学', 1),
#  ('剧里', 1),
#  ('男主', 1),
#  ('说白了', 1),
#  ('她', 1),
#  ('要', 1),
#  ('2', 1),
#  ('下', 1),
#  ('一句', 1),
#  ('话', 1),
#  ('恰烂', 1),
#  ('收', 1),
#  ('鹿晗', 1),
#  ('他俩', 1),
#  ('姓', 1),
#  ('鹿', 1),
#  ('哈哈哈', 1),
#  ('真有', 1),
#  ('这么', 1),
#  ('的话', 1),
#  ('把', 1),
#  ('他', 1),
#  ('挂', 1),
#  ('出来', 1),
#  ('3', 1),
#  ('可以', 1),
#  ('获奖', 1),
#  ('为什么', 1),
#  ('不能', 1),
#  ('挨骂', 1),
#  ('？', 1),
#  ('4', 1),
#  ('评价', 1),
# ...

# %%
ana.set_stop_words("停用词.txt")
text=" ".join(text)
text1=ana.extract_tags(text,topK=500)
text1=" ".join(text1)
text1
# Out:
# '凭剧 菜品 粉丝 演员 微笑 剧里 尼玛 这剧 男主 恰烂 鹿晗 sb Name Length 前女友 脑瘫 两亿 臭气熏天 徒有虚名 就是 挨骂 加大力度 学学 哈哈哈 丢脸 说白了 说真的 女友 厨师 菜肴 花钱 获奖 他俩 分手 真有 居然 评价 叫做 这次 一句 为什么 眼睛 的话 资本 这么 国内 出来 时候 因为 不能 投资 可以'

# %%
mask=np.array(Image.open("电1.jpg"))
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
ys=WordCloud(background_color="white",font_path="Font/msyh.ttc",max_words=500,width=250,height=250,repeat=False,max_font_size=70,min_font_size=10,mask=mask,colormap="RdPu")

# %%
ys.generate(text1)

# %%
ys.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1028x998 at 0x20DA581C670>

# %%
ys.recolor()

# %%
ys.to_file("影视区评论.png")
