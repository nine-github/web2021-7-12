# %%
from wordcloud import WordCloud
import numpy as np
import jieba
from snownlp import SnowNLP
import pandas as pd
from PIL import Image
import os
import jieba.analyse as ana
import nltk

# %%
data=pd.read_excel('评论区/生活区用户信息.xlsx',header=None,usecols = [6],squeeze  = False)
data
# Out:
#                                                       6
# 0                                               comment
# 1                       快来加入我们！共同守护和传承中华优秀传统文化！[脱单doge]
# 2            著名豫剧艺术家常香玉在抗美援朝的时候用一百七十多场的演出收入为志愿军捐赠了一架战斗机
# 3                               当年轻人爱上传统文化，真中！[热词系列_吹爆]
# 4                                  树梢绝美！豫剧绝美！洛阳绝美！河南绝美！
# ...                                                 ...
# 4542                                           别投币，标题党！
# 4543  提个建议：从上期开始，视频后期剪辑转镜太快了，看得人眼花+头晕，不如以前自然流畅，另外色彩上...
# 4544                                    爸爸们，带我上热搜[doge]
# 4545  准备了两个多月的豫剧表演，终于完成啦！作为初学者的一次尝试，还有很多很多不足，还请多包含啊！...
# 4546                                               哇，第一
#
# [4547 rows x 1 columns]

# %%
data= data.apply(lambda x: str(x))

# %%
text=data.values.tolist()
text=" ".join(text)
text=jieba.lcut(text)

# %%
fdist=nltk.FreqDist(text)
fdist.most_common(500)
# Out:
# [(' ', 356),
#  ('\n', 11),
#  ('，', 11),
#  ('！', 10),
#  ('的', 4),
#  ('绝美', 4),
#  ('[', 3),
#  (']', 3),
#  ('豫剧', 3),
#  ('了', 3),
#  ('...', 3),
#  (':', 3),
#  ('传统', 2),
#  ('文化', 2),
#  ('doge', 2),
#  ('上', 2),
#  (',', 2),
#  ('0', 1),
#  ('comment', 1),
#  ('1', 1),
#  ('快', 1),
#  ('来', 1),
#  ('加入', 1),
#  ('我们', 1),
#  ('共同', 1),
#  ('守护', 1),
#  ('和', 1),
#  ('传承', 1),
#  ('中华', 1),
#  ('优秀', 1),
#  ('脱单', 1),
#  ('2', 1),
#  ('著名', 1),
#  ('艺术家', 1),
#  ('常香玉', 1),
#  ('在', 1),
#  ('抗美援朝', 1),
#  ('时候', 1),
#  ('用', 1),
#  ('一百七十多', 1),
#  ('场', 1),
#  ('演出', 1),
#  ('收入', 1),
#  ('为', 1),
#  ('志愿军', 1),
#  ('捐赠', 1),
#  ('一架', 1),
#  ('战斗机', 1),
#  ('3', 1),
#  ('当', 1),
#  ('年轻人', 1),
#  ('爱上', 1),
#  ('真', 1),
#  ('中', 1),
#  ('热词', 1),
#  ('系列', 1),
#  ('_', 1),
#  ('吹', 1),
#  ('爆', 1),
#  ('4', 1),
#  ('树梢', 1),
#  ('洛阳', 1),
#  ('河南', 1),
#  ('4542', 1),
#  ('别', 1),
#  ('投币', 1),
#  ('标题', 1),
#  ('党', 1),
#  ('4543', 1),
#  ('提个', 1),
#  ('建议', 1),
# ...

# %%
ana.set_stop_words("停用词.txt")
text=" ".join(text)
text1=ana.extract_tags(text,topK=500)
text1=" ".join(text1)
text1
# Out:
# '绝美 豫剧 doge 投币 一百七十多 comment 脱单 热词 4542 4543 转镜 4544 4545 4546 Name Length 4547 dtype object 初学者 常香玉 看得人 传统 提个 剪辑 很多很多 文化 眼花 抗美援朝 树梢 爱上 传承 上期 太快 守护 志愿军 头晕 捐赠 流畅 视频 艺术家 多月 战斗机 一架 标题 尝试 中华 年轻人 表演 爸爸 优秀 演出 色彩 系列 包含 洛阳 后期 不如 加入 著名 不足 共同 终于 以前 收入 建议 河南 第一 自然 另外 完成 准备 一次 时候 作为 两个 还有 开始 我们'

# %%
mask=np.array(Image.open("电1.jpg"))
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
sh=WordCloud(background_color="white",font_path="Font/msyh.ttc",max_words=500,width=250,height=250,repeat=False,max_font_size=70,min_font_size=10,mask=mask,colormap="RdPu")

# %%
sh.generate(text1)

# %%
sh.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1028x998 at 0x242F250FE80>

# %%
sh.recolor()

# %%
sh.to_file("生活区评论.png")
