# %%
from wordcloud import WordCloud
import numpy as np
import jieba
from snownlp import SnowNLP
import pandas as pd
from PIL import Image
import os

# %%
import jieba.analyse as ana

# %%
import nltk

# %%
path="鬼畜区弹幕"
filenames=os.listdir(path)
result="鬼畜区弹幕.txt"
f= open(result, 'w+', encoding="utf-8")

# %%
for filename in filenames:
    filepath = path + '/'
    filepath = filepath + filename
    for line in open(filepath, encoding="utf-8"):
        f.writelines(line)
        f.write('\n')
f.close()

# %%
file=open(result,"r",encoding='utf-8')
text=file.read()
text=" ".join(jieba.lcut(text))

# %%
fdist=nltk.FreqDist(text)
fdist.most_common(500)
# Out:
# [(' ', 40716),
#  ('\n', 12982),
#  ('哈', 5911),
#  ('h', 4570),
#  ('？', 1086),
#  ('哦', 933),
#  ('了', 809),
#  ('草', 555),
#  ('好', 504),
#  ('o', 445),
#  ('！', 413),
#  ('H', 380),
#  ('，', 379),
#  ('一', 330),
#  ('这', 327),
#  ('我', 323),
#  ('的', 317),
#  ('是', 290),
#  ('离', 282),
#  ('谱', 273),
#  ('不', 260),
#  ('你', 245),
#  ('话', 240),
#  ('笑', 218),
#  ('3', 214),
#  ('来', 210),
#  ('a', 177),
#  ('字', 168),
#  ('大', 167),
#  ('或', 164),
#  ('听', 161),
#  ('个', 157),
#  ('人', 156),
#  ('w', 151),
#  ('《', 149),
#  ('》', 149),
#  ('♂', 146),
#  ('.', 142),
#  ('死', 140),
#  ('e', 140),
#  ('b', 138),
#  ('搁', 136),
#  ('住', 134),
#  ('。', 132),
#  ('0', 128),
#  ('席', 125),
#  ('蚌', 119),
#  ('埠', 119),
#  ('?', 117),
#  ('燃', 117),
#  ('就', 115),
#  ('么', 115),
#  ('有', 113),
#  ('起', 113),
#  ('!', 113),
#  ('k', 112),
#  ('啊', 111),
#  ('典', 111),
#  ('明', 103),
#  ('1', 102),
#  ('目', 101),
#  ('2', 100),
#  ('天', 100),
#  ('s', 99),
#  ('泪', 97),
#  ('呢', 95),
# ...

# %%
ana.set_stop_words("停用词.txt")
text1=ana.extract_tags(text,topK=1000)
text1=" ".join(text1)
text1
# Out:
# '哈哈哈 哈哈哈哈 哦哦哦 离谱 蚌埠 一席话 好好 草草 泪目 听君 哈哈 好活 燃起 前方 典中典 逆天 火钳 盖亚 lbwnb 刘明 核能 卧槽 比博燃 wake ohhhhhhh 杰哥 door wu 字字 救命 8000 太草 搁着 梦幻 套娃 skr 起立 联动 yeah 奥特曼 doge 阿伟 僵尸 炮姐 废话 高能 欧西 胜听 魔理沙 四个 别念 BGM bgm 最帅 废话连篇 想来想去 禁止 三句话 呜呜 恍恍惚惚 论文 2333 kksk ohhhhhhhhhhhhhhhh 辱彬逊 什么 封面 好家伙 不行 233333 LBWNB fa 越来越 说唱 吼吼 字正腔圆 填词 合理 漫长 彬彬 这个 两分钟 哈哈大笑 全明星 红红火火 贡子哥 xswl 23333 属于 上头 伞兵 奈克 阴间 冰冰 调音 三连 瑟斯 冰城 这儿 确实 视频 离大谱 nb 不是 酵母 就是 百万 大清 犀利 升华 放屁 标题 这么 生物 加油 弹幕 男性 讲师 八岁 活字印刷 制作 蜜雪 2333333 10 老八 好怪 男人 反清复明 百草园 小鬼 真的 已经 害怕 万句 忘记 怎么 扫帚 文艺复兴 666 你币 乱入 hhhhhh 鬼畜 18 ohhhhhhhhhhhhhhhhhhhh Wake woo ci 魔法 口诀 老师 还好 哇塞 怀念 大明 新生代 神来 闭环 回过 逐渐 原地 大臣 倍速 报菜名 一键 不住 现状 一个 时候 三味书屋 绝活 全体 日暮 所以 写作文 老总 好评 反复强调 碳基 爷青回 hhhhhhhhhhh 古尔丹 up ohhhhhhhhhhhhhhhhhhhhh ohhhhhhhhhhhhhhhhhh ohhhh ohhhhhhhhhhhhhhhhh 牛批 阿嬷 捷德 卢本伟 之巅 金轮法王 比博人 传燃 sala lei 欧系 倒放 还是 可以 一句 一遍 热乎 可乐 接地 字典 厕所 耳机 逻辑 爹爹 三块 作文 合眼 以为 直呼 原版 鬼才 流弊 不要 听懂 没有 冷静 雷姆 燃爆 屁话 天德 知道 大笑 药丸 啊啊啊 光轮 猛男 师傅 下次 龙虾 典型 斗兽 开始 相声 新华字典 这句 严谨 内行 狂喜 雪王 逆大天 cao 之大谱 金贡 扎心 hhhh .... 李荣浩 雀食 进度条 while er 有个 ohh
# ...

# %%
mask=np.array(Image.open("电1.jpg"))
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
gc=WordCloud(background_color="white",font_path="Font/msyh.ttc",max_words=500,width=250,height=250,repeat=False,max_font_size=70,min_font_size=10,mask=mask,colormap="RdPu")

# %%
gc.generate(text1)

# %%
gc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1028x998 at 0x15C8FBA7C70>

# %%
gc.recolor()

# %%
gc.to_file("鬼畜区弹幕.png")
