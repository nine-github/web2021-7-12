# %%
from wordcloud import WordCloud
import numpy as np
import jieba
from snownlp import SnowNLP
import pandas as pd
from PIL import Image
import os
import jieba.analyse as ana
import nltk

# %%
path="舞蹈区弹幕"
filenames=os.listdir(path)
result="舞蹈区弹幕.txt"
f= open(result, 'w+', encoding="utf-8")

# %%
for filename in filenames:
    filepath = path + '/'
    filepath = filepath + filename
    for line in open(filepath, encoding="utf-8"):
        f.writelines(line)
        f.write('\n')
f.close()

# %%
file=open(result,"r",encoding='utf-8')
text=file.read()
text=" ".join(jieba.lcut(text))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\DELL\AppData\Local\Temp\jieba.cache
# Loading model cost 0.535 seconds.
# Prefix dict has been built successfully.

# %%
fdist=nltk.FreqDist(text)
fdist.most_common(500)
# Out:
# [(' ', 56980),
#  ('\n', 17314),
#  ('啊', 2869),
#  ('！', 2226),
#  ('了', 1966),
#  ('好', 1344),
#  ('的', 1207),
#  ('我', 1005),
#  ('耀', 925),
#  ('文', 922),
#  ('刘', 861),
#  ('，', 841),
#  ('绝', 743),
#  ('太', 678),
#  ('舞', 659),
#  ('是', 623),
#  ('哈', 576),
#  ('这', 561),
#  ('不', 561),
#  ('帅', 549),
#  ('轩', 514),
#  ('一', 505),
#  ('来', 494),
#  ('霖', 464),
#  ('你', 463),
#  ('亚', 422),
#  ('贺', 420),
#  ('浩', 416),
#  ('宋', 415),
#  ('严', 414),
#  ('翔', 396),
#  ('爱', 379),
#  ('看', 368),
#  ('h', 363),
#  ('峻', 363),
#  ('人', 346),
#  ('台', 346),
#  ('有', 341),
#  ('？', 317),
#  ('个', 256),
#  ('天', 256),
#  ('y', 251),
#  ('表', 248),
#  ('真', 246),
#  ('么', 239),
#  ('小', 237),
#  ('能', 225),
#  ('上', 219),
#  ('呜', 219),
#  ('可', 218),
#  ('1', 203),
#  ('情', 200),
#  ('子', 197),
#  ('老', 196),
#  ('棒', 196),
#  ('就', 193),
#  ('哥', 193),
#  ('i', 191),
#  ('s', 190),
#  ('力', 189),
#  ('欢', 186),
#  ('美', 184),
#  ('热', 182),
#  ('分', 180),
#  ('都', 177),
#  ('喜', 176),
#  ('吧', 169),
#  ('。', 168),
#  ('跳', 168),
#  ('命', 164),
#  ('2', 157),
#  ('3', 157),
#  ('王', 156),
#  ('疯', 152),
#  ('～', 152),
#  ('主', 151),
#  ('点', 149),
#  ('l', 149),
#  ('钟', 149),
#  ('蒸', 149),
#  ('理', 147),
#  ('直', 146),
#  ('离', 145),
#  ('到', 143),
#  ('乎', 143),
#  ('全', 142),
#  ('光', 141),
#  ('6', 141),
#  ('会', 141),
#  ('管', 137),
#  ('在', 136),
#  ('要', 134),
#  ('头', 134),
#  ('d', 131),
#  ('谱', 131),
#  ('猫', 130),
#  ('萍', 129),
#  ('t', 128),
#  ('~', 127),
#  ('高', 127),
#  ('间', 127),
#  ('没', 126),
#  ('感', 125),
#  ('遍', 125),
#  ('眼', 123),
#  ('呀', 122),
#  ('救', 122),
#  ('无', 121),
#  ('a', 120),
#  ('p', 119),
#  ('出', 118),
#  ('动', 116),
#  ('r', 116),
#  ('鲨', 114),
#  ('还', 113),
#  ('公', 112),
#  ('o', 111),
#  ('啦', 111),
#  ('杀', 110),
#  ('也', 109),
#  ('牛', 107),
#  ('宝', 106),
#  ('场', 106),
#  ('生', 105),
#  ('他', 104),
#  ('神', 103),
#  ('时', 102),
#  ('回', 102),
#  ('发', 102),
#  ('再', 100),
#  ('得', 100),
#  ('以', 99),
#  ('开', 96),
#  ('很', 96),
#  ('喵', 96),
#  ('现', 95),
#  ('联', 95),
#  ('ღ', 95),
#  ('姐', 94),
#  ('每', 94),
#  ('起', 92),
#  ('三', 91),
#  ('们', 91),
#  ('着', 89),
#  ('日', 88),
#  ('者', 88),
#  ('服', 87),
#  ('家', 87),
#  ('亮', 87),
#  ('道', 86),
#  ('死', 86),
#  ('前', 85),
#  ('n', 83),
#  ('觉', 83),
#  ('位', 82),
#  ('又', 82),
#  ('伢', 80),
#  ('妈', 79),
#  ('唱', 79),
#  ('什', 78),
#  ('心', 78),
#  ('爷', 78),
#  ('0', 78),
#  ('通', 77),
#  ('度', 77),
#  ('限', 77),
#  ('担', 77),
#  ('多', 76),
#  ('青', 76),
#  ('A', 76),
#  ('笑', 76),
#  ('信', 75),
#  ('气', 75),
#  ('5', 75),
#  ('钓', 75),
#  ('乐', 74),
#  ('只', 74),
#  ('g', 74),
#  ('愧', 74),
#  ('卡', 73),
#  ('吗', 73),
#  ('下', 73),
#  ('9', 73),
#  ('歌', 72),
#  ('酱', 72),
#  ('才', 71),
#  ('机', 71),
#  ('贴', 71),
#  ('婆', 70),
#  ('最', 69),
#  ('接', 69),
#  ('定', 69),
#  ('为', 69),
#  ('年', 68),
#  ('永', 67),
#  ('远', 67),
#  ('哇', 67),
#  ('里', 67),
#  ('对', 67),
#  ('中', 66),
#  ('亿', 66),
#  ('c', 66),
#  ('少', 66),
#  ('过', 65),
#  ('伙', 64),
#  ('快', 64),
#  ('漂', 64),
#  ('蝶', 63),
#  ('入', 62),
#  ('C', 61),
#  ('方', 61),
#  ('耶', 60),
#  ('k', 60),
#  ('嗓', 60),
#  ('之', 59),
#  ('滴', 59),
#  ('级', 59),
#  ('\u200b', 59),
#  ('害', 58),
#  ('怎', 58),
#  ('白', 58),
#  ('蝴', 58),
#  ('-', 57),
#  ('!', 56),
#  ('听', 56),
#  ('呐', 56),
#  ('进', 56),
#  ('后', 56),
#  ('秒', 56),
#  ('强', 55),
#  ('厉', 55),
#  ('风', 55),
#  ('目', 55),
#  ('藏', 54),
#  ('说', 54),
#  ('衣', 53),
#  ('身', 53),
#  ('谁', 53),
#  ('电', 52),
#  ('烟', 52),
#  ('槽', 52),
#  ('沐', 51),
#  ('蹈', 51),
#  ('期', 51),
#  ('值', 51),
#  ('咬', 51),
#  ('成', 50),
#  ('b', 50),
#  ('拍', 50),
#  ('控', 50),
#  ('梦', 49),
#  ('狂', 49),
#  ('逼', 49),
#  ('明', 49),
#  ('作', 49),
#  ('面', 48),
#  ('.', 48),
#  ('自', 48),
#  ('超', 48),
#  ('芒', 47),
#  ('见', 46),
#  ('H', 46),
#  ('漠', 46),
#  ('哪', 46),
#  ('播', 46),
#  ('惊', 45),
#  ('内', 45),
#  ('手', 45),
#  ('儿', 45),
#  ('那', 45),
#  ('系', 45),
#  ('世', 45),
#  ('贝', 45),
#  ('粉', 45),
#  ('张', 44),
#  ('u', 44),
#  ('夺', 44),
#  ('地', 43),
#  ('卧', 43),
#  ('8', 43),
#  ('像', 42),
#  ('女', 42),
#  ('越', 42),
#  ('防', 41),
#  ('错', 41),
#  ('未', 41),
#  ('妹', 41),
#  ('醋', 41),
#  ('血', 41),
#  ('咿', 41),
#  ('活', 40),
#  ('格', 40),
#  ('7', 40),
#  (',', 40),
#  ('·', 40),
#  ('音', 40),
#  ('闪', 40),
#  ('双', 39),
#  ('w', 39),
#  ('比', 39),
#  ('别', 39),
#  ('把', 39),
#  ('般', 39),
#  ('国', 38),
#  ('打', 38),
#  ('腿', 38),
#  ('界', 38),
#  ('皮', 38),
#  ('仙', 38),
#  ('万', 38),
#  ('弟', 38),
#  ('4', 38),
#  ('呢', 37),
#  ('流', 37),
#  ('阿', 37),
#  ('长', 37),
#  ('男', 37),
#  ('想', 37),
#  ('反', 37),
#  ('学', 37),
#  ('做', 36),
#  ('带', 36),
#  ('去', 36),
#  ('娱', 36),
#  ('清', 36),
#  ('移', 35),
#  ('合', 35),
#  ('炸', 35),
#  ('极', 34),
#  ('实', 34),
#  ('脸', 34),
#  ('于', 34),
#  ('被', 34),
#  ('而', 34),
#  ('临', 34),
#  ('E', 34),
#  ('连', 33),
#  ('已', 33),
#  ('…', 33),
#  ('和', 33),
#  ('萌', 33),
#  ('注', 33),
#  ('简', 33),
#  ('财', 33),
#  ('膜', 32),
#  ('颜', 32),
#  ('视', 32),
#  ('变', 32),
#  ('掌', 32),
#  ('领', 32),
#  ('猖', 32),
#  ('选', 31),
#  ('业', 31),
#  ('种', 31),
#  ('经', 31),
#  ('样', 31),
#  ('演', 31),
#  ('知', 31),
#  ('完', 30),
#  ('走', 30),
#  ('灵', 30),
#  ('应', 30),
#  ('给', 30),
#  ('总', 30),
#  ('团', 29),
#  ('用', 29),
#  ('憨', 29),
#  ('迎', 29),
#  ('舒', 29),
#  ('第', 29),
#  ('西', 29),
#  ('燃', 29),
#  ('红', 29),
#  ('冷', 29),
#  ('排', 28),
#  ('行', 28),
#  ('两', 28),
#  ('空', 28),
#  ('事', 28),
#  ('豆', 28),
#  ('乖', 28),
#  ('草', 27),
#  ('次', 27),
#  ('精', 27),
#  ('哦', 27),
#  ('奏', 27),
#  ('香', 27),
#  ('刚', 27),
#  ('睛', 27),
#  ('石', 27),
#  ('己', 27),
#  ('妙', 27),
#  ('凡', 27),
#  ('爽', 27),
#  ('吸', 26),
#  ('净', 26),
#  ('呼', 26),
#  ('P', 26),
#  ('稳', 26),
#  ('代', 26),
#  ('穿', 25),
#  ('然', 25),
#  ('半', 25),
#  ('花', 25),
#  ('e', 25),
#  ('费', 25),
#  ('搞', 25),
#  ('步', 25),
#  ('更', 25),
#  ('跟', 25),
#  ('七', 25),
#  ('关', 25),
#  ('春', 25),
#  ('帧', 25),
#  ('苏', 25),
#  ('孩', 24),
#  ('倍', 24),
#  ('妥', 24),
#  ('终', 24),
#  ('够', 24),
#  ('优', 24),
#  ('息', 24),
#  ('刷', 24),
#  ('背', 24),
#  ('争', 24),
#  ('水', 23),
#  ('敏', 23),
#  ('让', 23),
#  ('楼', 23),
#  ('如', 23),
#  ('降', 23),
#  ('桃', 23),
#  ('哒', 23),
#  ('靠', 23),
#  ('L', 23),
#  ('\u2006', 23),
#  ('夏', 23),
#  ('磁', 23),
#  ('卷', 22),
#  ('味', 22),
#  ('必', 22),
#  ('细', 22),
#  ('海', 22),
#  ('叫', 22),
#  ('干', 21),
#  ('骗', 21),
#  ('谢', 21),
#  ('师', 21),
#  ('边', 21),
#  ('原', 21),
#  ('赞', 21),
#  ('适', 21),
#  ('批', 21),
#  ('需', 21),
#  ('秀', 21),
#  ('艺', 21),
#  ('节', 21),
#  ('击', 21),
#  ('落', 21),
#  ('九', 21),
#  ('即', 21),
#  ('校', 20),
#  ('新', 20),
#  ('差', 20),
#  ('幕', 20),
#  ('段', 20),
#  ('先', 20),
#  ('制', 20),
#  ('星', 20),
#  ('O', 20),
#  ('畅', 20),
#  ('毫', 20),
#  ('受', 20),
#  ('玫', 20),
#  ('瑰', 20),
#  ('珍', 20),
#  ('马', 19),
#  ('站', 19),
#  ('诈', 19),
#  ('满', 19),
#  ('镜', 19),
#  ('字', 19),
#  ('意', 19),
#  ('装', 19),
#  ('甩', 19),
#  ('正', 19),
#  ('依', 19),
#  ('飞', 19),
#  ('皇', 19),
#  ('质', 19),
#  ('魅', 19),
#  ('火', 19),
#  ('撩', 19),
#  ('友', 19),
#  ('线', 19),
#  ('勾', 19),
#  ('旧', 19),
#  ('脉', 19),
#  ('恋', 19),
#  ('请', 18)]

# %%
ana.set_stop_words("停用词.txt")
text1=ana.extract_tags(text,topK=1000)
text1=" ".join(text1)
text1
# Out:
# '刘耀文 啊啊啊 宋亚轩 贺峻霖 严浩翔 舞台 好帅 太帅 热乎 太绝 yyds 离谱 表情 哈哈哈 主舞 救命 喜欢 真的 老公 好看 呜呜 好绝 蒸蒸日上 分钟 亿遍 爷青回 舞担 严王 不愧 killing 管理 全能 高能 跳舞 卧槽 好家伙 文哥 联通 无限 可爱 萍萍 绝绝子 人间 蝴蝶 夺命 这个 霖霖 太棒了 王者 轩哥 天才 老婆 直拍 part 直播间 哈哈哈哈 ACE 漂亮 永远 好好看 刘耀 舞蹈 我来 钓系 滴浩翔 主场 厉害 贴膜 Artist 好棒 这么 沐哥 力度 电信 耀眼 咬人 宝贝 太强 天生 猖狂 光芒 爱豆 了不起 就是 贺儿 感觉 小时 可以 掌控 宝藏 唱歌 帅帅 轩轩 妈粉 绝子 动作 哈哈 一帧 接着 争气 防道 浩翔 上头 怎么 磁石 前方 闪耀 开头 卡点机 每一秒 好听 卡点 七秒 位领 西财 你好 衣服 表现力 绝杀 值得 甩头 好活 up rap 耀文 弹幕 少年 奏乐 前排 什么 欢迎 不是 姐姐 简直 我要 疯批 18 923 娱有 猫猫 绝美 双倍 漠漠 快乐 珍藏 绝对 严浩翔生 仙子 帅哥 极乐 诈骗 移动 视觉 boy 15 楼有 小贺 目光 精灵 美美 净土 出息 控制力 眼神 玫瑰 惊鸿 沧海 联动 舒服 瞩目 毫不费力 我选 我人 严总香 苏神 刘耀文绝 小萌 好美 恭喜 降临 人格 少女 董卓 进入 表演 好会 夏天 帅气 九敏 万般 清冷 未来 一生 一定 血脉 气场 期许 你们 好好 我们 不凡 每天 血槽 爱死 沐妥 颜值 内娱 发光 三连 流畅 来到 梦幻 美人 表现 眼睛 承包 临场 一绝 直接 666 boys 逆天 亚轩 刘耀文内 文太绝 artist 注定 依旧 梦回 世界 全程 全开 弟弟 光膀子 感谢 张飞 有点 一遍 为什么 青春 魅力 不够 般的 皮肤 恋爱 反应 优秀 努力 老师 帅死 最棒 嗓绝 再刷 25 吸粉 xnb TOP 我发 我爱你 不错 血洗 发现 高级 时代 亮眼 差错 还是 姐妹 白皮 白猫 折服 好强 偶像 全都 哪有 下凡 付出 细节 燃起 一级 太爱 哇哇 四分钟 唱点 学姐 实力 之王 到位 享受 doge 呼哈 比博燃 帅炸 天呐 太棒 好稳 有主舞 好野好 923923 乖乖 哥哥 那个 文帅 这里 左边 击中 天花板 封神 嗓音 自己 知道 需要 超级 起来 美貌 完美 性感 五虎上将 变质 风格 很棒 芒种 一面 热热 在线 超绝 妈妈 背后 经典 不发 地方 call 绝绝 阿伟 入坑 6657upup 空屏 浩帅 娱之光 吻文 惊艳 养成 三分钟 古筝 终于 出不来 蹦迪 身材 信任 没有 极度 镜头 猛男 一个 震撼 浓妆淡抹 神仙 六道 硬币 疯狂 灵魂 过年 闪闪发光 黄磊 YYDS 漠子哥 太牛 这腿 已空 我天 病娇 真帅 Top 男模 太钓 criminal 念多 小桃杏 声泠泠 犹抱 琵琶半 掩真 20 UP 一点点 好长 游刃有余 芜湖 明明 中国联通 太爽了 先帝 截图 呼吸机 太漂亮 这场 之光 台风 抬头 男孩 必要 美神 醉过 刘备 造型 头发 这样 亭亭 芭蕉 谨防 小宋 一直 刚刚 笑盈盈 看到 妹妹 手指 一秒 哪里 离不开 惊喜 中心 学校 小姐姐 风情 樱桃 越来越 打破 俏皮 哪个 美好 一脸 母爱 这是 适合 更新 整活 妥妥 以振 未半 带感 豪爵 滴神 美死 云袖 情越 6657 16 30 嗓好 25s 颜王 用颜值 top 文卡点 跳成 妈呀 领域 绝好 味道 一点 已经 进步 恋歌 中道 一样 为啥 关羽 选择 相信 耳机 魂魄 就要 芳泽 干嘛 咿呀 原版 后面 焦点 魅惑 绫罗 易碎 全世界 拥有 突出 曹操 舒适 不要 拿来 觉得 我妈 百看不厌 棒棒 艺术品 背景 跳得 漫长 整年 第一 看一遍 开眼 夸夸 投币 热门 多多 看见 回来 框架 清纯 桃源 现场 热爱 事故 毕业 两分钟 狙击 文艺复兴 五分钟 结义 小朋友 创业 蜀国 君子 救救 来看 视频 出来 瞬间 差评 君君 点赞 三卡三待 萍萍萍 萍萍萍萍 牛哇 woc 99 芽芽 很绝 wave 我太爱 好白 17 儿崽变 神级 帅到 红猫 清荷 引蝶 呐呐 好苏 10 13 22 欣小萌 翔哥 严浩翔帅 担靠 涨粉 战损 浩翔会 yjjc 学妹 我财 片尾 只能 有山有水 落落 穿衣服 宝宝 脸蛋 每个 优越 转身 只会 三家 好快 总是 小孩 更好 杀人 难舍 旗袍 沦陷 好像 回眸 赵云 还有 吕布 春风 一分钟 不会 全场 一下 司马懿 不能 一键 拖泥带水 看看 关注 名字 手机 雾里 爆炸 金钗 时候 确定 好久 开始 朵朵 深海 想起 几多 军心 力道 这套 七分钟 好爽 服装 诸葛亮 太有 是不是 太太 满分 节奏感 国风 夹子 期待 循环 做到 双胞胎 真是 好开心 摄人心魄 默默 轻轻 高跟鞋 能力 香客 系列 氛围 镜像 真实 孔明 还原 百万 形容 自带 明天 认真 靠靠 风月 无敌 每日 八分钟 阿姨 貌似 不到 声音 影子 两个 身上 整场 世上 仙女 着火 天神 白衣 羞涩 竟然 马冬梅 666666 位是 66666 2333 那味 牛哒 沐歌 帅帅帅 6666 同款 bgm jawill 这不比 nb 好辣 很帅 300 真绝 超棒 百变 我命 太赞 真秀 ... 我能 九敏九敏 钓死 排面 鲨死 giao 名贺峻霖 阿霖 賀峻霖 病娇感 感拉满 青回 莲华 执扇 音阙 49 maisaonv 感绝 嗓太绝 阿严 胜火 小严 浩绝 有壁 稳呐 苏到 这妈 这种 三国 顺畅 裂开 加油 居然 官方 吼吼 也好 只是 今天 长成 到底 好评 输出 播放 垄断 迷人 摸鱼 小熊 深刻 发光体 下次 想象 过于 以为 必须 根本 音乐 演唱 一只 一种 小兔子 一次 时间 校友 处理 过来 气质 属于 散发 鞋跟 存在 双子 充满 欢乐 你们好 有生之年 不行 精致 三分 希望 花红 舞步 赏心悦目 妙法 专业 干净利落 琢磨 前面 看不到 气息 各位 雷击 文化 手部 高中生 公子 狠狠 请问 助兴 辛苦 临危 简历 继续 犯规 流量 后脑勺 渔网 笑容 朋友 铁塔 完全 热乎乎 退出 如何 第一次 如其 来者 人家 荒野 非正常 门面 桃园 应该 装扮 好怪 钢化 潘凤 一夜 那么 盛开 挡不住 心动 英雄 骨子里 上楼 一天 那套 胭脂 轻盈 光华 片刻 屏幕 每次 果子 极强 之神 蒸汽机 邢道荣 冷美人 倍速 驾驭 多少 属实 全身 游历 熟悉 阵前 注入 招生 尖叫 日出 星光 味儿 上去 点卡 反应力 舞王 医学生 治愈 天使 上衣 花钱 多出 别念 坷垃 哈兰德 好乖 六分钟 美腿 反复 一看 后期 要死 全部 动感地带 六道轮回 打卡 符合 事情 活儿 不得不 雨刮器 挪不开 小宝贝 甜蜜蜜 纨扇 香香 太甜 顶上去 不了 小孩子 所有 艺术家 移不动 太卷 離譜 运镜 分晋 我币 太瘦 xswl 这群 Moskou 果果 好耶好 林子祥 妥子哥 魔性 233333 23333 一萍 伢哥 牙牙 hhhh 真高 真三国 能燃 ohhhhhhh 牛批 55 留赞 腾格尔 腿毛 gie ohhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh 未半而 阵险 亢歌 带错 太草 编舞 NB 爆燃 这怕 侧颜 隐韧 长手 轩爹 idol 我滴 word 蛊王 妈耶 帅拉 酷炫 夸起来 可甜 可盐 不活 衣架子 太勾人 这小 居敏 你币 这卡点 超稳 贺爹 后速来 手好 不惊 好絕 太絕 哇偶 用脸 词来 事是 是品 破局 看不腻 我头 我施 抬眸 贺哥 钓而 臭宝 空荡 DNA piu 颜表立 截屏 歌真 有音 1.25 00 最火 愛了 42 40 美哭 ..... wa wow 23 21 19 1111'

# %%
mask=np.array(Image.open("电1.jpg"))
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
wd=WordCloud(background_color="white",font_path="Font/msyh.ttc",max_words=500,width=250,height=250,repeat=False,max_font_size=70,min_font_size=10,mask=mask,colormap="RdPu")

# %%
wd.generate(text1)

# %%
wd.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1028x998 at 0x201644D37C0>

# %%
wd.recolor()

# %%
wd.to_file("舞蹈区弹幕.png")
