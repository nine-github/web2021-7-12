# %%
from wordcloud import WordCloud
import numpy as np
import jieba
from snownlp import SnowNLP
import pandas as pd
from PIL import Image
import os
import jieba.analyse as ana
import nltk

# %%
path="时尚区弹幕"
filenames=os.listdir(path)
result="时尚区弹幕.txt"
f= open(result, 'w+', encoding="utf-8")

# %%
for filename in filenames:
    filepath = path + '/'
    filepath = filepath + filename
    for line in open(filepath, encoding="utf-8"):
        f.writelines(line)
        f.write('\n')
f.close()

# %%
file=open(result,"r",encoding='utf-8')
text=file.read()
text=" ".join(jieba.lcut(text))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\DELL\AppData\Local\Temp\jieba.cache
# Loading model cost 0.543 seconds.
# Prefix dict has been built successfully.

# %%
fdist=nltk.FreqDist(text)
fdist.most_common(500)
# Out:
# [(' ', 60499),
#  ('\n', 21242),
#  ('1', 4387),
#  ('哈', 3820),
#  ('！', 2592),
#  ('我', 2558),
#  ('了', 1877),
#  ('好', 1383),
#  ('看', 1165),
#  ('的', 1095),
#  ('啊', 996),
#  ('保', 977),
#  ('护', 962),
#  ('，', 802),
#  ('不', 796),
#  ('可', 743),
#  ('这', 740),
#  ('太', 692),
#  ('是', 671),
#  ('姐', 497),
#  ('会', 476),
#  ('？', 467),
#  ('有', 465),
#  ('个', 443),
#  ('2', 432),
#  ('一', 395),
#  ('美', 371),
#  ('要', 324),
#  ('8', 306),
#  ('爱', 298),
#  ('么', 274),
#  ('就', 272),
#  ('来', 270),
#  ('你', 256),
#  ('0', 253),
#  ('味', 250),
#  ('真', 248),
#  ('子', 247),
#  ('呜', 244),
#  ('人', 229),
#  ('3', 214),
#  ('出', 212),
#  ('h', 208),
#  ('牛', 201),
#  ('以', 180),
#  ('到', 180),
#  ('。', 177),
#  ('吧', 174),
#  ('9', 170),
#  ('像', 165),
#  ('都', 165),
#  ('吗', 164),
#  ('也', 163),
#  ('哇', 162),
#  ('大', 158),
#  ('还', 157),
#  ('想', 155),
#  ('5', 153),
#  ('为', 151),
#  ('绝', 151),
#  ('6', 151),
#  ('心', 149),
#  ('发', 148),
#  ('婆', 145),
#  ('眼', 144),
#  ('香', 142),
#  ('很', 142),
#  ('死', 139),
#  ('!', 137),
#  ('说', 137),
#  ('妆', 135),
#  ('去', 134),
#  ('那', 134),
#  ('没', 134),
#  ('刀', 133),
#  ('点', 132),
#  ('女', 129),
#  ('得', 128),
#  ('老', 128),
#  ('分', 124),
#  ('o', 123),
#  ('学', 123),
#  ('哥', 123),
#  ('笑', 122),
#  ('头', 121),
#  ('…', 119),
#  ('什', 117),
#  ('在', 116),
#  ('多', 116),
#  ('用', 116),
#  ('天', 115),
#  ('法', 113),
#  ('小', 112),
#  ('上', 112),
#  ('内', 112),
#  ('能', 111),
#  ('样', 109),
#  ('觉', 105),
#  ('7', 105),
#  ('三', 102),
#  ('同', 102),
#  ('手', 101),
#  ('医', 99),
#  ('感', 97),
#  ('生', 97),
#  ('下', 96),
#  ('贴', 96),
#  ('水', 92),
#  ('毛', 92),
#  ('啦', 91),
#  ('疯', 91),
#  ('对', 88),
#  ('自', 87),
#  ('皮', 86),
#  ('.', 85),
#  ('u', 82),
#  ('面', 82),
#  ('画', 82),
#  ('呀', 81),
#  ('化', 81),
#  ('话', 80),
#  ('p', 79),
#  ('色', 79),
#  ('里', 77),
#  ('槽', 77),
#  ('喷', 77),
#  ('前', 76),
#  ('卧', 76),
#  ('儿', 76),
#  ('钟', 76),
#  ('b', 75),
#  ('道', 75),
#  ('白', 74),
#  ('别', 74),
#  ('腌', 73),
#  ('开', 72),
#  ('魔', 72),
#  ('肤', 72),
#  ('愿', 71),
#  ('容', 71),
#  ('热', 70),
#  ('精', 70),
#  ('们', 70),
#  ('康', 69),
#  ('m', 69),
#  ('家', 69),
#  ('入', 68),
#  ('做', 67),
#  ('种', 66),
#  ('害', 66),
#  ('w', 64),
#  ('喜', 64),
#  ('抽', 63),
#  ('连', 63),
#  ('4', 63),
#  ('行', 63),
#  ('欢', 62),
#  ('妹', 62),
#  ('脸', 62),
#  ('时', 62),
#  ('娘', 62),
#  ('g', 61),
#  ('厉', 61),
#  ('妈', 61),
#  ('长', 61),
#  ('男', 61),
#  ('实', 60),
#  ('亮', 60),
#  ('啥', 60),
#  ('然', 60),
#  ('直', 60),
#  ('眉', 60),
#  ('本', 59),
#  ('显', 59),
#  ('款', 59),
#  ('穿', 58),
#  ('比', 57),
#  ('致', 57),
#  ('哦', 56),
#  ('带', 56),
#  ('身', 56),
#  ('求', 55),
#  ('起', 55),
#  ('完', 55),
#  ('神', 54),
#  ('衣', 54),
#  ('怎', 53),
#  ('只', 53),
#  ('高', 53),
#  ('许', 52),
#  ('e', 52),
#  ('a', 52),
#  ('中', 51),
#  ('漂', 51),
#  ('正', 50),
#  ('张', 50),
#  ('溜', 50),
#  ('蚊', 50),
#  ('院', 50),
#  ('现', 49),
#  ('i', 49),
#  ('颜', 49),
#  ('接', 48),
#  ('换', 48),
#  ('变', 48),
#  ('气', 47),
#  ('意', 47),
#  ('主', 46),
#  ('命', 46),
#  ('救', 45),
#  ('之', 45),
#  ('过', 45),
#  ('常', 45),
#  ('服', 45),
#  ('动', 44),
#  ('次', 44),
#  ('但', 44),
#  ('逼', 44),
#  ('己', 44),
#  ('术', 44),
#  ('l', 43),
#  ('刚', 43),
#  ('光', 43),
#  ('定', 43),
#  ('裙', 43),
#  ('最', 42),
#  ('c', 42),
#  ('又', 42),
#  ('瞳', 42),
#  ('知', 42),
#  ('粉', 41),
#  ('给', 41),
#  ('原', 41),
#  ('打', 41),
#  ('乎', 41),
#  ('吓', 41),
#  ('着', 40),
#  ('和', 40),
#  ('鼻', 40),
#  ('睫', 40),
#  ('草', 40),
#  ('闻', 40),
#  ('体', 39),
#  ('～', 39),
#  ('文', 39),
#  ('买', 38),
#  ('合', 37),
#  ('线', 37),
#  ('谢', 36),
#  ('睛', 36),
#  ('超', 36),
#  ('（', 35),
#  ('k', 35),
#  ('哪', 35),
#  ('强', 35),
#  ('底', 35),
#  ('d', 35),
#  ('干', 35),
#  ('甲', 35),
#  ('重', 34),
#  ('件', 34),
#  ('特', 34),
#  ('后', 34),
#  ('口', 33),
#  ('机', 33),
#  ('呢', 33),
#  ('问', 33),
#  ('达', 33),
#  ('咩', 33),
#  ('安', 33),
#  ('全', 32),
#  ('经', 32),
#  ('试', 32),
#  ('该', 32),
#  ('放', 32),
#  ('第', 32),
#  ('把', 32),
#  ('修', 32),
#  ('两', 32),
#  ('黑', 32),
#  ('洗', 32),
#  ('阿', 31),
#  ('视', 31),
#  ('果', 31),
#  ('品', 31),
#  ('他', 31),
#  ('整', 31),
#  ('n', 30),
#  ('错', 30),
#  ('油', 30),
#  ('s', 30),
#  ('骨', 30),
#  ('更', 30),
#  ('包', 30),
#  ('弹', 29),
#  ('已', 29),
#  ('非', 29),
#  ('量', 29),
#  ('才', 29),
#  ('音', 29),
#  ('刻', 29),
#  ('）', 28),
#  ('棒', 28),
#  ('她', 28),
#  ('幕', 28),
#  ('快', 28),
#  ('~', 28),
#  ('影', 28),
#  ('被', 28),
#  ('咋', 28),
#  ('边', 28),
#  ('所', 28),
#  ('外', 28),
#  ('适', 28),
#  ('柏', 28),
#  ('孩', 27),
#  ('频', 27),
#  ('少', 27),
#  ('嘛', 27),
#  ('靠', 26),
#  ('让', 26),
#  ('如', 26),
#  ('制', 26),
#  ('因', 26),
#  ('难', 26),
#  ('惊', 26),
#  ('倩', 26),
#  ('每', 25),
#  ('y', 25),
#  ('事', 25),
#  ('宝', 25),
#  ('间', 25),
#  ('笔', 25),
#  ('蓝', 25),
#  ('露', 25),
#  ('晴', 25),
#  ('冲', 24),
#  ('晚', 24),
#  ('关', 24),
#  ('华', 24),
#  ('推', 24),
#  ('期', 24),
#  ('办', 24),
#  ('效', 24),
#  ('日', 24),
#  ('跟', 24),
#  ('新', 24),
#  ('确', 24),
#  ('候', 24),
#  ('芝', 24),
#  ('卸', 24),
#  ('素', 24),
#  ('钱', 23),
#  ('红', 23),
#  ('辣', 23),
#  ('围', 23),
#  ('乖', 23),
#  ('拉', 22),
#  ('拿', 22),
#  ('方', 22),
#  ('伙', 22),
#  ('注', 22),
#  ('教', 22),
#  ('谁', 22),
#  ('腰', 22),
#  ('胖', 22),
#  ('麻', 22),
#  ('加', 21),
#  ('花', 21),
#  ('西', 21),
#  ('耶', 21),
#  ('荐', 21),
#  ('仙', 21),
#  ('嗷', 21),
#  ('王', 21),
#  ('B', 21),
#  ('几', 21),
#  ('成', 21),
#  ('质', 21),
#  ('师', 21),
#  ('情', 21),
#  ('称', 21),
#  ('欧', 20),
#  ('慕', 20),
#  ('应', 20),
#  ('友', 20),
#  ('t', 20),
#  ('假', 20),
#  ('吸', 20),
#  ('无', 20),
#  ('明', 20),
#  ('懂', 20),
#  ('疼', 20),
#  ('般', 20),
#  ('瘦', 20),
#  ('套', 20),
#  ('：', 20),
#  ('嘴', 20),
#  ('币', 19),
#  ('地', 19),
#  ('活', 19),
#  ('搞', 19),
#  ('突', 19),
#  ('根', 19),
#  ('门', 19),
#  ('而', 19),
#  ('万', 19),
#  ('怕', 19),
#  ('士', 19),
#  ('息', 19),
#  ('血', 19),
#  ('规', 19),
#  ('免', 19),
#  ('疫', 19),
#  ('巴', 18),
#  ('型', 18),
#  ('双', 18),
#  ('?', 18),
#  ('病', 18),
#  ('再', 18),
#  ('平', 18),
#  ('部', 18),
#  ('诶', 18),
#  ('差', 18),
#  ('刷', 18),
#  ('山', 18),
#  ('奇', 18),
#  ('十', 18),
#  ('复', 18),
#  ('选', 17),
#  ('近', 17),
#  ('走', 17),
#  ('先', 17),
#  ('二', 17),
#  ('科', 17),
#  ('公', 17),
#  ('D', 17),
#  ('吃', 17),
#  ('镜', 17),
#  ('题', 17),
#  ('找', 17),
#  ('理', 17),
#  ('乐', 17),
#  ('退', 17),
#  ('尔', 17),
#  ('易', 17),
#  ('液', 17),
#  ('信', 16),
#  ('飞', 16),
#  ('其', 16),
#  ('收', 16),
#  ('配', 16),
#  ('必', 16),
#  ('怪', 16),
#  ('级', 16),
#  ('肩', 16),
#  ('肉', 16),
#  ('挺', 16),
#  ('值', 16),
#  ('年', 16),
#  ('性', 16),
#  ('指', 16),
#  ('云', 16),
#  ('听', 16),
#  ('妃', 16),
#  ('雾', 16),
#  ('取', 16),
#  ('越', 16),
#  ('剑', 16),
#  ('些', 15),
#  ('(', 15),
#  ('位', 15),
#  ('盘', 15),
#  ('算', 15),
#  ('M', 15),
#  ('见', 15),
#  ('细', 15),
#  ('粗', 15),
#  ('形', 15),
#  ('声', 15),
#  ('当', 15),
#  ('尼', 15),
#  ('迪', 15),
#  ('国', 15),
#  ('投', 15),
#  ('帽', 15),
#  ('需', 14),
#  ('挑', 14),
#  ('哭', 14),
#  ('键', 14),
#  ('东', 14),
#  ('力', 14),
#  ('业', 14),
#  ('嘿', 14),
#  ('肯', 14),
#  ('敢', 14),
#  ('夏', 14),
#  ('条', 14),
#  ('膏', 14),
#  ('通', 14)]

# %%
ana.set_stop_words("停用词.txt")
text1=ana.extract_tags(text,topK=1000)
text1=" ".join(text1)
text1
# Out:
# '哈哈哈 保护 哈哈哈哈 好看 啊啊啊 10 11111 111111 1111 姐姐 我要 刀哥 111 爱看 1111111 卧槽 不可 真的 呜呜 这个 好美 11111111 up 内味 好好看 魔法 同款 太牛 看看 哈哈 贴心 入味 老婆 可可 可以 味儿 三连 许愿 可爱 学到 厉害 婆娘 11 香水 好像 美女 康康 救命 bgm 精致 这么 喜欢 化妆 蚊子 热乎 想要 就是 皮肤 感觉 分钟 睫毛 说话 弹幕 漂亮 张柏芝 医院 三甲 小倩 什么 眉毛 有点 哇哇 腌制 美瞳 我愿 好家伙 为什么 姐妹 味道 视频 头发 修容 太好了 围裙 觉得 妈呀 眼影 不是 衣服 不会 好多 怎么 好乖 溜溜 那个 文文 高光 好白 眼睛 心动 好长 香味 好好 学会 绝绝子 素颜 直接 太强 女生 换头 woc 22222 依云 医美 自己 适合 这样 医生 这种 喷雾 为啥 免疫 这是 一个 我来 发量 正规 没有 有点像 投币 不行 闻到 知道 吓死 同意 doge 2D BGM 太绝 华妃 刻晴 一键 称之为 这件 小姐姐 辣妹 黑头 喷香 天呐 222222 8888 易容术 男生 化妆品 前面 但是 推荐 这里 自带 还是 一样 吓人 卸妆 你好 哇塞 谢谢 出来 好会 刘心悠 握草 保護 刀嫂 222 一点 身上 每次 香气 搞笑 蜻蜓 鼻子 颜色 确实 剑法 眉骨 不能 好闻 干杯 试试 本来 手办 看到 一定 更好 裙子 底子 999 2222 ... cos nb 瞳色 体香 好大 整容 花露水 日常 妈妈 我们 微胖 超级 混血 不去 腮红 应该 一下 窒息 不错 